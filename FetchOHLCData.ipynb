# %%
import pandas as pd
import yfinance as yf

# Load your Excel file and read stock tickers
excel_file = 'Modified_Round_1_Excel_Assessment.xlsx'
df = pd.read_excel(excel_file, sheet_name='Sheet 2')  # assuming stock data is in 'Sheet 2'

# Add columns for Open, High, Low, Close
df[['Open', 'High', 'Low', 'Close']] = None

for idx, row in df.iterrows():
    stock_id = row['Security Id']  # or whichever column holds the ticker

    # Attempt to fetch data from BSE
    stock_data = yf.download(f"{stock_id}.BO", start="2024-10-28", end="2024-10-29")

    # If BSE data is empty or unavailable, try fetching from NSE
    if stock_data.empty or 'Open' not in stock_data.columns:
        print(f"Attempting to fetch NSE data for {stock_id}")
        stock_data = yf.download(f"{stock_id}.NS", start="2024-10-28", end="2024-10-29")

    # Check if we successfully fetched data and if it contains the necessary columns
    if not stock_data.empty and 'Open' in stock_data.columns:
        try:
            # Extract scalar values using .iloc[0].item() to avoid adding entire row
            df.at[idx, 'Open'] = stock_data['Open'].iloc[0].item()
            df.at[idx, 'High'] = stock_data['High'].iloc[0].item()
            df.at[idx, 'Low'] = stock_data['Low'].iloc[0].item()
            df.at[idx, 'Close'] = stock_data['Close'].iloc[0].item()
        except (IndexError, ValueError) as e:
            print(f"Error for stock {stock_id}: {e}")
    else:
        print(f"No data available for stock {stock_id} on either BSE or NSE in the given date range.")

# Save to a new Excel file
df.to_excel("Combined_Stock_Data.xlsx", index=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['3IINFOTECH.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['3IINFOTECH.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Attempting to fetch NSE data for 3IINFOTECH
# No data available for stock 3IINFOTECH on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['7NR.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for 7NR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['7NR.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock 7NR on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMFL.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMFL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMFL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AMFL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AINFRA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AINFRA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AINFRA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AINFRA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AAL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AAL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARCOM.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AARCOM
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARCOM.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AARCOM on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARSHYAM.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AARSHYAM
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARSHYAM.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AARSHYAM on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AREYDRG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AREYDRG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AREYDRG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AREYDRG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARNAV.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AARNAV
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARNAV.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AARNAV on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARVINFRA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AARVINFRA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AARVINFRA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AARVINFRA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASWTR.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ASWTR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASWTR.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ASWTR on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABHIJIT.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABHIJIT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABHIJIT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ABHIJIT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABHIFIN.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ABHIFIN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABHIFIN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABHIFIN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACEWIN.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ACEWIN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACEWIN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ACEWIN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACRYSIL.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ACRYSIL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACRYSIL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ACRYSIL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACTIONFI.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ACTIONFI
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACTIONFI.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACTIVE.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock ACTIONFI on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for ACTIVE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACTIVE.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ACTIVE on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADANIGAS.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADANIGAS
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADANIGAS.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADANIGAS on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADANITRANS.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADANITRANS
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADANITRANS.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ADANITRANS on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADARSH.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADARSH
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADARSH.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ADARSH on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASRL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ASRL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASRL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ASRL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADHARSHILA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADHARSHILA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADHARSHILA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ADHARSHILA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADHUNIKIND.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADHUNIKIND
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADHUNIKIND.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADHUNIKIND on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADITRI.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADITRI
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADITRI.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADITRI on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLBANETF.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ABSLBANETF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLNN50ET.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ABSLNN50ET
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5DD.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF5DD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5DD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5DG.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock ABSLRIF5DD on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for ABSLRIF5DG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5DG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF5DG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5RD.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ABSLRIF5RD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5RD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5RG.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock ABSLRIF5RD on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for ABSLRIF5RG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF5RG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF5RG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6DD.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF6DD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6DD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF6DD on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6DG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF6DG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6DG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF6DG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6RD.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF6RD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6RD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF6RD on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6RG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF6RG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF6RG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF6RG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7DD.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF7DD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7DD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF7DD on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7DG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF7DG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7DG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF7DG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7RD.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF7RD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7RD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF7RD on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7RG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ABSLRIF7RG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABSLRIF7RG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ABSLRIF7RG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3DD.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for BSLRIFS3DD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3DD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3DG.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock BSLRIFS3DD on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for BSLRIFS3DG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3DG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3RD.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock BSLRIFS3DG on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for BSLRIFS3RD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3RD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock BSLRIFS3RD on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3RG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for BSLRIFS3RG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS3RG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4DD.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock BSLRIFS3RG on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for BSLRIFS4DD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4DD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4DG.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock BSLRIFS4DD on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for BSLRIFS4DG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4DG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4RD.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock BSLRIFS4DG on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for BSLRIFS4RD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4RD.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock BSLRIFS4RD on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4RG.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for BSLRIFS4RG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BSLRIFS4RG.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock BSLRIFS4RG on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADORFO.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ADORFO
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADORFO.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADORFO on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADVPETR-B.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ADVPETR-B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADVPETR-B.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADVPETR-B on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADVENT.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADVENT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADVENT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADVENT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADVITIYA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ADVITIYA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADVITIYA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ADVITIYA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AFFORDABLE.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AFFORDABLE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AGCNET.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AGCNET
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AGCNET.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AGCNET on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AGRIMONY.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AGRIMONY
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AGRIMONY.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AGRIMONY on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIMCOPEST.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AIMCOPEST
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIMCOPEST.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AIMCOPEST on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AISHWARYA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AISHWARYA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AISHWARYA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AISHWARYA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AJWAFUN.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AJWAFUN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AJWAFUN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AJWAFUN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AKASHDEEP.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AKASHDEEP
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AKASHDEEP.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AKASHDEEP on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AKM.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AKM
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AKM.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AKM on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASHFL.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ASHFL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASHFL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ASHFL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AKSCHEM.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AKSCHEM
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AKSCHEM.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AKSCHEM on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALSL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ALSL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALSL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ALSL on either BSE or NSE in the given date range.
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['SCOTT.BO', 'ALAN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [                       0%                       ]
# Attempting to fetch NSE data for ALAN SCOTT
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['ALAN', 'SCOTT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ALAN SCOTT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALBERTDA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ALBERTDA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALBERTDA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ALBERTDA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AREALTY.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AREALTY
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AREALTY.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AREALTY on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALEXANDER.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ALEXANDER
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALEXANDER.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ALEXANDER on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALKA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ALKA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALKA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ALKA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIML.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AIML
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIML.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AIML on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALOKTEXT.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ALOKTEXT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALOKTEXT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ALOKTEXT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALSTONE.BO']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Attempting to fetch NSE data for ALSTONE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ALSTONE.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ALSTONE on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMANITRA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMANITRA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMANITRA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AMANITRA on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMARAJABAT.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMARAJABAT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMARAJABAT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AMARAJABAT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMARSEC.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AMARSEC
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMARSEC.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AMARSEC on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMAZEENT.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMAZEENT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMAZEENT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AMAZEENT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMBARPIL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AMBARPIL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMBARPIL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIHL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock AMBARPIL on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for AIHL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AIHL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AIHL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMINTAN.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AMINTAN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMINTAN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AMINTAN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMITINT.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for AMITINT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMITINT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AMITINT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMITSEC.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMITSEC
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMITSEC.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AMITSEC on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMARDEE.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMARDEE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMARDEE.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock AMARDEE on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACFSL.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ACFSL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACFSL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock ACFSL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMRAFIN.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMRAFIN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMRAFIN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AMRAFIN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMRITCORP.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for AMRITCORP
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMRITCORP.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock AMRITCORP on either BSE or NSE in the given date range.
# ...
#
# 1 Failed download:
# ['WSFIN.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WSFIN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WSFIN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WSFIN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WARDINMOBI.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for WARDINMOBI
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WARDINMOBI.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WARDINMOBI on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WEBSL.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WEBSL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WEBSL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WEBSL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WEIZFIN.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WEIZFIN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WEIZFIN.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WEIZFIN on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELCON.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WELCON
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELCON.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WELCON on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELLESLEY.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WELLESLEY
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELLESLEY.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock WELLESLEY on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELLNESS.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WELLNESS
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELLNESS.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WELLNESS on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELSPUNIND.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WELSPUNIND
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELSPUNIND.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WELSPUNIND on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELSPLSOL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for WELSPLSOL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELSPLSOL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELTI.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock WELSPLSOL on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for WELTI
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WELTI.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WELTI on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WESTLEIRES.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for WESTLEIRES
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WESTLEIRES.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock WESTLEIRES on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WMINIMT.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WMINIMT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WMINIMT.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WMINIMT on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WORL.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for WORL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WORL.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WORL on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WINROC.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WINROC
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WINROC.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WINROC on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WINTAC.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for WINTAC
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WINTAC.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock WINTAC on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WOODSVILA.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for WOODSVILA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WOODSVILA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WWALUM.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock WOODSVILA on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for WWALUM
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WWALUM.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# No data available for stock WWALUM on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WORTH.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for WORTH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['YASHPAKKA.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for YASHPAKKA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['YASHPAKKA.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['YASTF.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# No data available for stock YASHPAKKA on either BSE or NSE in the given date range.
# Attempting to fetch NSE data for YASTF
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['YASTF.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock YASTF on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZFSTEERING.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-10-28 -> 2024-10-29)')
# Attempting to fetch NSE data for ZFSTEERING
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZFSTEERING.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ZFSTEERING on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZENITHBIR.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ZENITHBIR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZENITHBIR.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ZENITHBIR on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZUARIGLOB.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for ZUARIGLOB
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZUARIGLOB.NS']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# No data available for stock ZUARIGLOB on either BSE or NSE in the given date range.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CDSL.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for CDSL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['VERTOZ.BO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Attempting to fetch NSE data for VERTOZ
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol for Adharshila Capital Services on BSE
ticker_symbol = '7NR.BO'  # Use .BO for BSE

# Fetch historical stock data for Adharshila Capital Services Ltd.
adharshila_data = yf.download(ticker_symbol, start='202-01-01', end='2023-01-31')

# Display the fetched data
print(adharshila_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['7NR.BO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2023-01-01 -> 2023-01-31)')
# Empty DataFrame
# Columns: [(Adj Close, 7NR.BO), (Close, 7NR.BO), (High, 7NR.BO), (Low, 7NR.BO), (Open, 7NR.BO), (Volume, 7NR.BO)]
# Index: []
